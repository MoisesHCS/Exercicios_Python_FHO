# %% [markdown]
# **Moisés Henrique Campanholo da Silva RA: 114518**

# %% [markdown]
# 1) Podem ser selecionados para um campeonato, candidatos (chamados elegíveis) segundo dois
# critérios: ano de início de graduação e ano de nascimento. No caso, um candidato é elegível se tem
# idade inferior a 35 anos ou menos de cinco anos de graduação. Faça um programa que leia o ano
# atual do concurso, o ano de ingresso do candidato na graduação e, por fim, o ano de seu nascimento.
# Assim, verifique se o candidato é ELEGÍVEL, caso contrário, informe INELEGÍVEL.

# %%
ano_atual = int(input("Digite o ano atual do curso:"))
ano_ingresso = int(input("Digite o ano de ingresso na graduação:"))
ano_nascimento = int(input("Digite o ano do seu nascimento:"))
anos_de_graduação = int(ano_atual-ano_ingresso)
idade = int(ano_atual-ano_nascimento)
if(anos_de_graduação < 5 or idade < 35 ):
  print("ELEGÍVEL")
else:
  print("INELEGÍVEL")
# Out:
# Digite o ano atual do curso:2005
# Digite o ano de ingresso na graduação:2000
# Digite o ano do seu nascimento:1990
# 5
# 15
# ELEGÍVEL

# %% [markdown]
# 2) Faça um programa que informe se um número é divisível por 3 e por 5 ao mesmo tempo.

# %%
n=int(input("digite um número:"))
r= n%3
r1=n%5
if( r == 0 and r1==0 ):
  print(' esse número é divisível por 3 e 5')
else:
   print(" esse numero não é divisivel por 3 e 5 ")
# Out:
# digite um numero:15
#  esse número é por 3 e 5

# %% [markdown]
# 3) Faça um programa que leia l1, l2 e l3, como os lados de um triângulo, e verifique se o triângulo
# é:

# %%
L1 = float(input("informe o primeiro lado: "))
L2 = float(input("informe o segundo lado: "))
L3 = float(input("informe o terceiro lado: "))


if(L1 == L2 and L2 == L3):
  print("EQUILÁTERO")
elif (L1 == L2 ) or (L3 == L2 ) or (L1 == L3):
  print("ISÓSCELES")
else:
  print("ESCALENO")
# Out:
# informe o primeiro lado: 2
# informe o segundo lado: 2
# informe o terceiro lado: 2
# EQUILÁTERO

# %% [markdown]
# 4) Faça um programa que calcule a nota de um aluno e informe a situação do aluno.

# %%
média = float(input("Informe a média:"))

if(média >= 5):
  print("Aprovado")
elif(média >= 3 ):
  print("RE")
else:
  print("Reprovado por nota")
# Out:
# Informe a média:10
# Aprovado

# %% [markdown]
# 5) Uma livraria está fazendo uma promoção para pagamento à vista em que o comprador pode
# escolher entre dois critérios de desconto:
#
# Critério A: R$ 0,25 por livro + R$ 7,50
# Critério B: R$ 0,50 por livro + R$ 2,50
#
# Faça um programa em que o usuário digita a quantidade de livros que deseja comprar e o programa
# calcula qual seria o valor do pagamento em ambos critérios. O programa deve afirma quais dos
# critérios é maior vantajoso.

# %%
CriterioA = int(input("informe o numero de Livros 'A' que quer comprar: "))

CriterioB = int(input("informe o numero de Livros 'B' que quer comprar:  "))

ValorA = (0,25 + 7,50)

ValorB = (0,50 + 2,50)

if(ValorA >= ValorB):
  print("Criterio 'B' é mais vantajoso que a Criterio A")
elif(ValorB >= ValorA):
  print("Criterio 'A' é mais vantajoso que a Criterio B")
# Out:
# informe o numero de Livros 'A' que quer comprar: 48
# informe o numero de Livros 'B' que quer comprar:  56
# Criterio A é mais vantajoso que a Criterio B

# %% [markdown]
# 6) Escreva um programa que solicite ao usuário que entre com as médias de 5 alunos e para cada
# aluno imprime se o mesmo está aprovado (>=5), reprovado (< 3) ou recuperação (>=3 e <5).

# %%
qtd = int(input("Informe a quantidade de alunos:"))
for i in range(qtd):
  média = float(input("Informe a média:"))
  if(média >= 5):
    print("Aprovado")
  elif(média >= 3 ):
    print("RE")
  else:
    print("Reprovado por nota")
# Out:
# Informe a quantidade de alunos:3
# Informe a média:6
# Aprovado
# Informe a média:8
# Aprovado
# Informe a média:3
# RE

# %% [markdown]
# 7) A cidade A possui 90.000 habitantes e a cidade B 50.000. A população da cidade A cresce 0,9 %
# ao ano enquanto que a da cidade B cresce 1,5% ao ano.
# Faça um programa que leia o número de anos e calcule qual será o número da população de cada
# cidade. O programa deve verificar se o tamanho da cidade A é maior que a cidade B, ou se o
# tamanho da cidade B é maior que a cidade A.

# %%
cidade_a = 90.000
cidade_b = 50.000
ano = int(input("informe quantos anos passou: "))

for tempo_ano in range(ano):
  cidade_a = (cidade_a * 1.009)

  cidade_b = (cidade_b * 1.015)

if(cidade_b >  cidade_a):
  print("Cidade B é maior que a Cidade A")
else:
  print("Cidade A é maior que a Cidade B")
# Out:
# informe quantos anos passou: 10
# Cidade A é maior que a Cidade B
