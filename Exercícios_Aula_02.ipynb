# %% [markdown]
# **Exercícios Aula 02**

# %% [markdown]
# 1) Reproduza os exemplos feitos em aula

# %% [markdown]
# Moisés Henrique Campanholo da Silva         RA: 114518

# %%
print("Olá Mundo!")
# Out:
# Olá Mundo!

# %%
print("Linha 1\nLinha 2")
# Out:
# Linha 1
# Linha 2

# %%
print("Coluna 1\tColuna 2")
# Out:
# Coluna 1	Coluna 2

# %%
print("Isso é uma barra invertida \\")
# Out:
# Isso é uma barra invertida \

# %%
print('Ele disse "Olá"')
print("Ele disse \"Olá\"")
# Out:
# Ele disse "Olá"
# Ele disse "Olá"

# %%
nome = "Moisés"   # Isso é uma variável chamada nome com o conteúdo Moisés
idade = 18        # Isso é uma variável chamada idade com o conteúdo 18
altura = 1.68     # Isso é uma varável chamada altura com o valor de 1.68


print(nome)
print(idade)
print(altura)

print("Nome =",nome, "Idade =", idade, "Altura =",altura)
# Out:
# Moisés
# 18
# 1.68
# Nome = Moisés Idade = 18 Altura= 1.68

# %%
print("Olá Mundo", end="! ")
print("Programação","de","Computadores",sep="-")
# Out:
# Olá Mundo! Programação-de-Computadores

# %%
nome = "Moisés"
idade = 18

print(f"Nome: {nome} Idade: {idade}")
# Out:
# Nome: Moisés Idade: 18

# %%
nome = input("Digite seu nome:")
print(f"Olá {nome}! Seja bem vindo!")
# Out:
# DIgite seu nome:Moisés
# Olá Moisés! Seja bem vindo!

# %%
x = input("Informe o valor de x:")
y = input("Informe o valor de y:")
z = int(x) + int(y)

print(f"Resultado da soma {z}")
# Out:
# Informe o valor de x:5
# Informe o valor de y:5
# Resultado da soma 10

# %% [markdown]
# 2) Leia o nome de uma pessoa e exiba uma mensagem de boas vindas

# %%
nome = input("Digite seu nome:")
print(f"Olá, {nome}! Seja bem vindo!")
# Out:
# Digite seu nome:Moisés
# Olá, Moisés! Seja bem vindo!

# %% [markdown]
# 3) Leia o dia, mês e o ano de nascimento do usuário e exiba a data na tela

# %%
dia = input("Digite o dia que você nasceu:")
mês = input("Digite o mês que você nasceu:")
ano = input("Digite o ano que você nasceu:")
print(f"Você nasceu dia {dia} de {mês} de {ano}")
# Out:
# Digite o dia que você nasceu:18
# Digite o mês que você nasceu:Maio
# Digite o ano que você nasceu:2005
# Você nasceu dia 18 de Maio de 2005
