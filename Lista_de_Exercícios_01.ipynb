# %% [markdown]
# **Lista de Exercícios**

# %% [markdown]
# Moisés Henrique Campanholo da Silva RA: 114518

# %% [markdown]
# 1) Faça um programa capaz de realizar a leitura do seu nome completo e seu curso. Imprima no
# console os respectivos inputs.

# %%
Nome = input("informe seu nome:")
Curso = input("imforme seu curso:")
print(f"Olá, {Nome}, seu curso é {Curso}. ")
# Out:
# informe seu nome:Moisés
# imforme seu curso:Engenharia da Computação
# Ola, Moisés, seu curso é Engenharia da Computação.

# %% [markdown]
# 2)Faça um programa capaz de realizar a leitura, de forma individual, do dia, mês e ano atual; utilize três variáveis para isso. Em seguida, imprima no console seguindo o seguinte padrão.

# %%
dia = input("Digite o dia: ")
mês = input("Digite o mês: ")
ano = input("Digite o ano: ")

print(f"{dia}/{mês}/{ano}")
# Out:
# Digite o dia: 29
# Digite o mês: 08
# Digite o ano: 2018
# 29/08/2018

# %% [markdown]
# 3) Faça um programa capaz de realizar a leitura, de forma individual, de uma hora qualquer, minuto
# e segundo, respectivamente. Em seguida, exiba no console seguindo o padrão a seguir.

# %%
Hora = input("digite a Hora:")
Min = input("digite o minuto:")
Seg = input("digite o segundo:")
print(f'{Hora} Horas {Min} Minutos {Seg} segundos')
# Out:
# digite a Hora:20
# digite o minuto:30
# digite o segundo:10
# 20 Horas 30 Minutos 10 segundos

# %% [markdown]
# 4)Faça um programa capaz de realizar leituras de contagens regressivas, partindo de três segundos.
# A cada número inserido pelo usuário, a saída já deve ser exibida logo em seguida. Supondo que o
# usuário digitou 3, no console já deve ser exibido “Faltam 3 segundos!!!”, e assim sucessivamente.

# %%
contagem3 = input("Digite a contagem: ")
print(f"Faltam {contagem3} segundos!")
contagem2 = input("Digite a contagem: ")
print(f"Faltam {contagem2} segundos!")
contagem1 = input("Digite a contagem: ")
print(f"Falta {contagem1} segundo!")
# Out:
# Digite a contagem: 3
# Faltam 3 segundos!
# Digite a contagem: 2
# Faltam 2 segundos!
# Digite a contagem: 1
# Falta 1 segundo!

# %% [markdown]
# 5) Modifique o exercício 4 seguindo o seguinte raciocínio: Exiba uma única mensagem no console
# pedindo para que o usuário digite, um a um, os três segundos regressivos. Após ler os três números,
# exiba em uma única mensagem a contagem (utilizando um único comando print).

# %%
print("Digite uma contagem regressiva de 3 segundos")
um = input("")
dois = input("")
três = input("")
print("Faltam 3 segundos!!! Faltam 2 segundos!!! Faltam apenas 1 segundo!!! ")
# Out:
# Digite uma contagem regressiva de 3 segundos
# 3
# 2
# 1
# Faltam 3 segundos!!! Faltam 2 segundos!!! Faltam apenas 1 segundo!!!

# %% [markdown]
# 6) Crie um programa simples que simule uma lista de supermercado, a qual pode guardar, no
# mínimo, três produtos. Peça ao usuário que digite os produtos a serem comprados, em seguida,
# mostre a relação completa no console.

# %%
print("**Bem-vindo à agenda eletrônica**")
p1 = input("Digite seu primeiro produto:")
p2 = input("digite seu segundo produto:")
p3 = input("digite seu terceiro produto:")
print(f"Usuário, você deve comprar os seguintes itens: {p1},{p2},{p3}.")
# Out:
# **Bem-vindo à agenda eletronica**
# Digite seu primeiro produto:maçã
# digite seu segundo produto:melão
# digite seu terceiro produto:banana
# Usuario, você deve comprar os seguintes intens: maçã,melão,banana.

# %% [markdown]
# 7) Continue o exercício 6 e acrescente agora a quantidade de itens de cada produto. Imprima no
# console o nome do produto e a quantidade dele.

# %%
print("**Bem-vindo à agenda eletrônica**")
p1 = input("Digite seu primeiro produto:")
q1 = input("Digite a quantidade:")
p2 = input("Digite seu segundo produto:")
q2 = input("Digite a quantidade:")
p3 = input("Digite seu terceiro produto:")
q3 = input("Digite a quantidade:")
print(f"Usuário, você deve comprar os seguintes itens: {q1} {p1},{q2} {p2},{q3} {p3}.")
# Out:
# **Bem-vindo à agenda eletrônica**
# Digite seu primeiro produto:maçã
# Digite a quantidade:1
# Digite seu segundo produto:morangos
# Digite a quantidade:3
# Digite seu terceiro produto:banana
# Digite a quantidade:1
# Usuario, você deve comprar os seguintes itens: 1 maçã,3 morangos,1 banana.

# %% [markdown]
# 8) Crie uma agenda eletrônica capaz de realizar a leitura dos dados de uma pessoa física (Nome
# completo, RG, CPF, celular, e-mail). Para cada dado, exiba uma frase autoexplicativa no console.
# Após realizar a leitura dos dados, imprima todos no console; logo após, peça ao usuário que
# confirme a ação, digitando SIM ou NÃO.

# %%
Nome = input("Olá! Qual é o seu nome completo ?:")
RG = input("RG:")
CPF = input("CPF:")
Cel = input("celular:")
email = input("e-mail:")
print(f"Você confirma se esses são seu dados ?:\n{Nome}\n{RG}\n{CPF}\n{Cel}\n{email}.")
input("")
# Out:
# Olá! Qual é o seu nome completo ?:Moisés Henrique Campanholo da Silva
# RG:5
# CPF:4
# celular:3
# e-mail:2
# Você confirma se esses são seu dados ?:
# Moisés Henrique Campanholo da Silva
# 5
# 4
# 3
# 2.
# SIM
# 'SIM'

# %% [markdown]
# 9) Crie um programa capaz de ler o nome do aluno, o RA, o curso e a disciplina que ele mais gosta
# até o momento. Depois, leia a média da disciplina e imprima tudo no console. Empregue a
# formatação que quiser e utilize um ou mais comandos print.

# %%
nome_aluno = input("Digite o nome do aluno: ")
ra = input("Digite o RA do aluno: ")
curso = input("Digite o curso do aluno: ")
disciplina_favorita = input("Digite a disciplina que o aluno mais gosta: ")
media_disciplina = input("Digite a média nessa disciplina:")
print(f"\nInformações do Aluno:\nNome do Aluno:{nome_aluno}\nRA do Aluno:{ra}\nCurso do Aluno: {curso}\nDisciplina Favorita:{disciplina_favorita}\nMédia na Disciplina: {media_disciplina}")
# Out:
# Digite o nome do aluno: Moisés
# Digite o RA do aluno: 114518
# Digite o curso do aluno: Engenharia de Computação
# Digite a disciplina que o aluno mais gosta: Cálculo
# Digite a média nessa disciplina:8
#
# Informações do Aluno:
# Nome do Aluno:Moisés
# RA do Aluno:114518
# Curso do Aluno: Engenharia de Computação
# Disciplina Favorita:Cálculo
# Média na Disciplina: 8
